# %%
import pandas as pd

# %%
df = pd.read_csv('CricketTestMatchData.csv')
df
# Out:
#                         Player       Span  Mat  Inns  NO  Runs    HS    Ave  \
# 0             DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94
# 1             PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66
# 2               AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87
# 3              RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97
# 4              GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83
# ..                         ...        ...  ...   ...  ..   ...   ...    ...
# 58           GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25
# 59           WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22
# 60             SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21
# 61  Hashmatullah Shahidi (AFG)  2018-2025   11    21   5   771   246  48.18
# 62            DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00
#
#        BF     SR  100  50     0    4s  6s
# 0   9800+  58.60   29  13   7.0  626+   6
# 1    2063  63.79    5   5   NaN   137  24
# 2    2667  55.68    5   4   2.0   186   5
# 3   1707+  54.48    7  11   1.0  246+  11
# 4    416+  56.00   10   5   2.0  104+   1
# ..    ...    ...  ...  ..   ...   ...  ..
# 58  15525  59.67   27  38  11.0  1165  24
# 59  3118+  44.77    7   6   1.0  119+   0
# 60  3217+  60.02    6  13   4.0  241+  5+
# 61   1629  47.32    2   2   NaN    87   1
# 62  2110+  25.59    1  10   2.0   53+   0
#
# [63 rows x 15 columns]

# %%
df = df.rename(columns = {
    'Mat': 'Matches',
    'NO': 'Not_Outs',
    'HS': 'Highest_Inns_Score',
    'BF': 'Balls_Faced',
    'SR': 'Batting_Strike_Rate'
})

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1  PHKD Mendis (SL)  2022-2025       14    24         3  1316
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 3   RG Pollock (SA)  1963-1970       23    41         4  2256
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 0                334  99.94       9800+                58.60   29  13  7.0
# 1               182*  62.66        2063                63.79    5   5  NaN
# 2               269*  61.87        2667                55.68    5   4  2.0
# 3                274  60.97       1707+                54.48    7  11  1.0
# 4               270*  60.83        416+                56.00   10   5  2.0
#
#      4s  6s
# 0  626+   6
# 1   137  24
# 2   186   5
# 3  246+  11
# 4  104+   1

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                       True
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81         5  4455
# 14       CL Walcott (WI)  1948-1960       44    74         7  3798
# 54  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 8                 207  58.61         NaN                  NaN   15  19  6.0
# 14                220  56.68         NaN                  NaN   15  14  1.0
# 54               144*  48.79         NaN                  NaN    5   6  3.0
#
#       4s  6s
# 8   258+   2
# 14  107+  11
# 54   51+   0

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Player']=='CL Walcott (WI)']
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 14  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 14                220  56.68           0                  0.0   15  14  1.0
#
#       4s  6s
# 14  107+  11

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# Length: 63, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s]
# Index: []

# %%
df[df['Player'].isin(['GA Headley (WI)', 'GS Sobers (WI)', 'JB Hobbs (ENG)', 'V Kohli (IND)'])]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
# 10   GS Sobers (WI)  1954-1974       93   160        21  8032
# 13   JB Hobbs (ENG)  1908-1930       61   102         7  5410
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50     0  \
# 4                270*  60.83        416+                56.00   10   5   2.0
# 10               365*  57.78       4063+                53.58   26  30  12.0
# 13                211  56.94       5363+                46.22   15  28   4.0
#
#       4s   6s
# 4   104+    1
# 10  593+  32+
# 13  276+    8

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['GA Headley (WI)', 'GS Sobers (WI)', 'JB Hobbs (ENG)', 'V Kohli (IND)'])]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
# 10   GS Sobers (WI)  1954-1974       93   160        21  8032
# 13   JB Hobbs (ENG)  1908-1930       61   102         7  5410
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50     0  \
# 4                270*  60.83        416+                56.00   10   5   2.0
# 10               365*  57.78       4063+                53.58   26  30  12.0
# 13                211  56.94       5363+                46.22   15  28   4.0
#
#       4s   6s
# 4   104+    1
# 10  593+  32+
# 13  276+    8

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2025]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 58    [2002, 2014]
# 59    [1924, 1934]
# 60    [1930, 1938]
# 61    [2018, 2025]
# 62    [1928, 1934]
# Name: Span, Length: 63, dtype: object

# %%
df['Span'].str.split(pat = '-').str[1]
# Out:
# 0     1948
# 1     2025
# 2     2016
# 3     1970
# 4     1954
#       ...
# 58    2014
# 59    1934
# 60    1938
# 61    2025
# 62    1934
# Name: Span, Length: 63, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df = df.drop(['Span'], axis = 1)

# %%
df.head()
# Out:
#              Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1  PHKD Mendis (SL)       14    24         3  1316               182*  62.66
# 2    AC Voges (AUS)       20    31         7  1485               269*  61.87
# 3   RG Pollock (SA)       23    41         4  2256                274  60.97
# 4   GA Headley (WI)       22    40         4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50    0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7.0  626+   6        1928
# 1        2063                63.79    5   5  NaN   137  24        2022
# 2        2667                55.68    5   4  2.0   186   5        2015
# 3       1707+                54.48    7  11  1.0  246+  11        1963
# 4        416+                56.00   10   5  2.0  104+   1        1930
#
#   Final_Year
# 0       1948
# 1       2025
# 2       2016
# 3       1970
# 4       1954

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0               [DG Bradman , AUS)]
# 1               [PHKD Mendis , SL)]
# 2                 [AC Voges , AUS)]
# 3                [RG Pollock , SA)]
# 4                [GA Headley , WI)]
#                   ...
# 58             [GC Smith , ICC/SA)]
# 59             [WH Ponsford , AUS)]
# 60               [SJ McCabe , AUS)]
# 61    [Hashmatullah Shahidi , AFG)]
# 62              [DR Jardine , ENG)]
# Name: Player, Length: 63, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country']
# Out:
# 0        AUS)
# 1         SL)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 58    ICC/SA)
# 59       AUS)
# 60       AUS)
# 61       AFG)
# 62       ENG)
# Name: Country, Length: 63, dtype: object

# %%
df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1         SL
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 58    ICC/SA
# 59       AUS
# 60       AUS
# 61       AFG
# 62       ENG
# Name: Country, Length: 63, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df['Player']
# Out:
# 0               DG Bradman
# 1              PHKD Mendis
# 2                 AC Voges
# 3               RG Pollock
# 4               GA Headley
#               ...
# 58                GC Smith
# 59             WH Ponsford
# 60               SJ McCabe
# 61    Hashmatullah Shahidi
# 62              DR Jardine
# Name: Player, Length: 63, dtype: object

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df
# Out:
#                    Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score  \
# 0             DG Bradman        52    80        10  6996                334
# 1            PHKD Mendis        14    24         3  1316               182*
# 2               AC Voges        20    31         7  1485               269*
# 3             RG Pollock        23    41         4  2256                274
# 4             GA Headley        22    40         4  2190               270*
# ..                    ...      ...   ...       ...   ...                ...
# 58              GC Smith       117   205        13  9265                277
# 59           WH Ponsford        29    48         4  2122                266
# 60             SJ McCabe        39    62         5  2748                232
# 61  Hashmatullah Shahidi        11    21         5   771                246
# 62            DR Jardine        22    33         6  1296                127
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50     0    4s  6s  \
# 0   99.94       9800+                58.60   29  13   7.0  626+   6
# 1   62.66        2063                63.79    5   5   NaN   137  24
# 2   61.87        2667                55.68    5   4   2.0   186   5
# 3   60.97       1707+                54.48    7  11   1.0  246+  11
# 4   60.83        416+                56.00   10   5   2.0  104+   1
# ..    ...         ...                  ...  ...  ..   ...   ...  ..
# 58  48.25       15525                59.67   27  38  11.0  1165  24
# 59  48.22       3118+                44.77    7   6   1.0  119+   0
# 60  48.21       3217+                60.02    6  13   4.0  241+  5+
# 61  48.18        1629                47.32    2   2   NaN    87   1
# 62  48.00       2110+                25.59    1  10   2.0   53+   0
#
#    Rookie_Year Final_Year Country
# 0         1928       1948     AUS
# 1         2022       2025      SL
# 2         2015       2016     AUS
# 3         1963       1970      SA
# 4         1930       1954      WI
# ..         ...        ...     ...
# 58        2002       2014  ICC/SA
# 59        1924       1934     AUS
# 60        1930       1938     AUS
# 61        2018       2025     AFG
# 62        1928       1934     ENG
#
# [63 rows x 17 columns]

# %%
df['Highest_Inns_Score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 58    277
# 59    266
# 60    232
# 61    246
# 62    127
# Name: Highest_Inns_Score, Length: 63, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0   DG Bradman        52    80        10  6996                 334  99.94
# 1  PHKD Mendis        14    24         3  1316                 182  62.66
# 2     AC Voges        20    31         7  1485                 269  61.87
# 3   RG Pollock        23    41         4  2256                 274  60.97
# 4   GA Headley        22    40         4  2190                 270  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50    0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7.0  626+   6        1928
# 1        2063                63.79    5   5  NaN   137  24        2022
# 2        2667                55.68    5   4  2.0   186   5        2015
# 3       1707+                54.48    7  11  1.0  246+  11        1963
# 4        416+                56.00   10   5  2.0  104+   1        1930
#
#   Final_Year Country
# 0       1948     AUS
# 1       2025      SL
# 2       2016     AUS
# 3       1970      SA
# 4       1954      WI

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                       True
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#              Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 8        ED Weekes        48    81         5  4455                 207  58.61
# 14      CL Walcott        44    74         7  3798                 220  56.68
# 54  Hon.FS Jackson        20    33         4  1415                 144  48.79
#
#    Balls_Faced  Batting_Strike_Rate  100  50    0    4s  6s Rookie_Year  \
# 8          NaN                  0.0   15  19  6.0  258+   2        1948
# 14         NaN                  0.0   15  14  1.0  107+  11        1948
# 54         NaN                  0.0    5   6  3.0   51+   0        1893
#
#    Final_Year Country
# 8        1958      WI
# 14       1960      WI
# 54       1905     ENG

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Country]
# Index: []

# %%
df[df['Player']=='ED Weekes ']
# Out:
#        Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 8  ED Weekes        48    81         5  4455                 207  58.61
#
#   Balls_Faced  Batting_Strike_Rate  100  50    0    4s 6s Rookie_Year  \
# 8           0                  0.0   15  19  6.0  258+  2        1948
#
#   Final_Year Country
# 8       1958      WI

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                       True
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                    Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0             DG Bradman        52    80        10   6996                 334
# 1            PHKD Mendis        14    24         3   1316                 182
# 2               AC Voges        20    31         7   1485                 269
# 3             RG Pollock        23    41         4   2256                 274
# 4             GA Headley        22    40         4   2190                 270
# 5            H Sutcliffe        54    84         9   4555                 194
# 6              E Paynter        20    31         5   1540                 243
# 7          KF Barrington        82   131        15   6806                 256
# 8              ED Weekes        48    81         5   4455                 207
# 9             WR Hammond        85   140        16   7249                 336
# 10             GS Sobers        93   160        21   8032                 365
# 11              HC Brook        30    50         1   2820                 317
# 12         KC Sangakkara       134   233        17  12400                 319
# 13              JB Hobbs        61   102         7   5410                 211
# 14            CL Walcott        44    74         7   3798                 220
# 15              L Hutton        79   138        15   6971                 364
# 16             SPD Smith       119   212        25  10477                 239
# 17             JH Kallis       166   280        40  13289                 224
# 18          GE Tyldesley        14    20         2    990                 122
# 19         KS Williamson       105   186        17   9276                 251
# 20              CA Davis        15    29         5   1301                 183
# 21             VG Kambli        17    21         1   1084                 227
# 22           GS Chappell        87   151        19   7110                 247
# 23             AD Nourse        34    62         7   2960                 231
# 24          SR Tendulkar       200   329        33  15921                 248
# 25               BC Lara       131   232         6  11953                 400
# 26         Javed Miandad       124   189        21   8832                 280
# 27              R Dravid       164   286        32  13288                 270
# 28       Mohammad Yousuf        90   156        12   7530                 223
# 29           Younis Khan       118   213        19  10099                 313
# 30            RT Ponting       168   287        29  13378                 257
# 31           YBK Jaiswal        26    49         2   2428                 214
# 32               J Ryder        20    32         5   1394                 201
# 33              A Flower        63   112        19   4794                 232
# 34            MEK Hussey        79   137        16   6235                 195
# 35         S Chanderpaul       164   280        49  11867                 203
# 36               JE Root       158   288        24  13543                 262
# 37           SM Gavaskar       125   214        16  10122                 236
# 38              SR Waugh       168   260        46  10927                 200
# 39             ML Hayden       103   184        14   8625                 380
# 40        AB de Villiers       114   191        18   8765                 278
# 41             AR Border       156   265        44  11174                 205
# 42          IVA Richards       121   182        12   8540                 291
# 43           DCS Compton        78   131        15   5807                 278
# 44      DPMD Jayawardene       149   252        15  11814                 374
# 45        Inzamam-ul-Haq       120   200        22   8830                 329
# 46           FMM Worrell        51    87         9   3860                 261
# 47               CP Mead        17    26         2   1185                 182
# 48              V Sehwag       104   180         6   8586                 319
# 49              Abid Ali        16    26         2   1180                 215
# 50             MJ Clarke       115   198        22   8643                 329
# 51              KC Bland        21    39         5   1669                 144
# 52            B Mitchell        42    80         9   3471                 189
# 53              JL Smith        15    25         3   1075                 184
# 54        Hon.FS Jackson        20    33         4   1415                 144
# 55        TT Samaraweera        81   132        20   5462                 231
# 56             RN Harvey        79   137        10   6149                 205
# 57            KD Walters        74   125        14   5357                 250
# 58              GC Smith       117   205        13   9265                 277
# 59           WH Ponsford        29    48         4   2122                 266
# 60             SJ McCabe        39    62         5   2748                 232
# 61  Hashmatullah Shahidi        11    21         5    771                 246
# 62            DR Jardine        22    33         6   1296                 127
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50     0     4s   6s  \
# 0   99.94        9800                58.60   29  13   7.0   626+    6
# 1   62.66        2063                63.79    5   5   NaN    137   24
# 2   61.87        2667                55.68    5   4   2.0    186    5
# 3   60.97        1707                54.48    7  11   1.0   246+   11
# 4   60.83         416                56.00   10   5   2.0   104+    1
# 5   60.73        6558                34.59   16  23   2.0   202+    6
# 6   59.23        1288                45.88    4   7   3.0   125+    4
# 7   58.67        4957                42.42   20  35   5.0   591+   27
# 8   58.61           0                 0.00   15  19   6.0   258+    2
# 9   58.45        7491                38.07   22  24   4.0   419+   27
# 10  57.78        4063                53.58   26  30  12.0   593+  32+
# 11  57.55        3222                87.52   10  13   3.0    308   47
# 12  57.40       22882                54.19   38  52  11.0   1491   51
# 13  56.94        5363                46.22   15  28   4.0   276+    8
# 14  56.68           0                 0.00   15  14   1.0   107+   11
# 15  56.67        2844                39.34   19  33   5.0   358+    7
# 16  56.02       19517                53.68   36  43  11.0   1143   62
# 17  55.37       28903                45.97   45  58  16.0   1488   97
# 18  55.00         178                29.21    3   6   2.0    37+    2
# 19  54.88       17913                51.78   33  37  11.0   1031   27
# 20  54.20         665                35.48    4   4   1.0    65+    1
# 21  54.20        1823                59.46    4   3   3.0    124    6
# 22  53.86       13079                51.53   24  31  12.0    755   16
# 23  53.81         108                63.88    9  14   3.0   115+    6
# 24  53.78       29437                54.04   51  68  14.0  2058+   69
# 25  52.88       19753                60.51   34  48  17.0   1559   88
# 26  52.57       15164                45.99   23  43   6.0   788+   48
# 27  52.31       31258                42.51   36  63   8.0   1654   21
# 28  52.29       14372                52.39   24  33  11.0    957   51
# 29  52.05       19375                52.12   34  33  19.0   1082   70
# 30  51.85       22782                58.72   41  62  17.0   1509   73
# 31  51.65        3655                66.42    7  12   5.0    301   43
# 32  51.62        2035                44.86    3   9   1.0   102+    3
# 33  51.54       10636                45.07   12  27   5.0    543   20
# 34  51.52       12436                50.13   19  29  12.0    685   39
# 35  51.37       27395                43.31   30  66  15.0   1285   36
# 36  51.29       23556                57.49   39  66  13.0   1451   45
# 37  51.12       14184                43.35   34  45  12.0   908+   26
# 38  51.06       22461                48.64   32  50  22.0   1175   20
# 39  50.73       14349                60.10   30  29  14.0   1049   82
# 40  50.66       16077                54.51   22  46   8.0   1024   64
# 41  50.56       27002                41.09   27  63  11.0   1161   28
# 42  50.23        9613                69.77   24  45  10.0   952+   84
# 43  50.06        2731                38.81   17  28  10.0   342+    3
# 44  49.84       22959                51.45   34  50  15.0   1387   61
# 45  49.60       16345                54.02   25  46  15.0   1105   48
# 46  49.48         488                40.16    9  22  11.0   240+   11
# 47  49.37         619                30.04    4   3   3.0    38+    0
# 48  49.34       10441                82.23   23  32  16.0   1233   91
# 49  49.16        2445                48.26    4   3   2.0    148    5
# 50  49.10       15456                55.92   28  27   9.0    978   39
# 51  49.08         885                37.74    3   9   2.0   123+   20
# 52  48.88         158                29.11    8  21   3.0    41+    1
# 53  48.86        1429                75.22    2   6   NaN    111   26
# 54  48.79           0                 0.00    5   6   3.0    51+    0
# 55  48.76       11641                46.92   14  30  11.0    633    7
# 56  48.41        1799                43.74   21  24   7.0   427+    1
# 57  48.26        8662                49.16   15  33   4.0   525+   23
# 58  48.25       15525                59.67   27  38  11.0   1165   24
# 59  48.22        3118                44.77    7   6   1.0   119+    0
# 60  48.21        3217                60.02    6  13   4.0   241+   5+
# 61  48.18        1629                47.32    2   2   NaN     87    1
# 62  48.00        2110                25.59    1  10   2.0    53+    0
#
#    Rookie_Year Final_Year  Country
# 0         1928       1948      AUS
# 1         2022       2025       SL
# 2         2015       2016      AUS
# 3         1963       1970       SA
# 4         1930       1954       WI
# 5         1924       1935      ENG
# 6         1931       1939      ENG
# 7         1955       1968      ENG
# 8         1948       1958       WI
# 9         1927       1947      ENG
# 10        1954       1974       WI
# 11        2022       2025      ENG
# 12        2000       2015       SL
# 13        1908       1930      ENG
# 14        1948       1960       WI
# 15        1937       1955      ENG
# 16        2010       2025      AUS
# 17        1995       2013   ICC/SA
# 18        1921       1929      ENG
# 19        2010       2024       NZ
# 20        1968       1973       WI
# 21        1993       1995      IND
# 22        1970       1984      AUS
# 23        1935       1951       SA
# 24        1989       2013      IND
# 25        1990       2006   ICC/WI
# 26        1976       1993      PAK
# 27        1996       2012  ICC/IND
# 28        1998       2010      PAK
# 29        2000       2017      PAK
# 30        1995       2012      AUS
# 31        2023       2025      IND
# 32        1920       1929      AUS
# 33        1992       2002      ZIM
# 34        2005       2013      AUS
# 35        1994       2015       WI
# 36        2012       2025      ENG
# 37        1971       1987      IND
# 38        1985       2004      AUS
# 39        1994       2009      AUS
# 40        2004       2018       SA
# 41        1978       1994      AUS
# 42        1974       1991       WI
# 43        1937       1957      ENG
# 44        1997       2014       SL
# 45        1992       2007  ICC/PAK
# 46        1948       1963       WI
# 47        1911       1928      ENG
# 48        2001       2013  ICC/IND
# 49        2019       2021      PAK
# 50        2004       2015      AUS
# 51        1961       1966       SA
# 52        1929       1949       SA
# 53        2024       2025      ENG
# 54        1893       1905      ENG
# 55        2001       2013       SL
# 56        1948       1963      AUS
# 57        1965       1981      AUS
# 58        2002       2014   ICC/SA
# 59        1924       1934      AUS
# 60        1930       1938      AUS
# 61        2018       2025      AFG
# 62        1928       1934      ENG

# %%
df = df.drop(56, axis = 0)

# %%
df
# Out:
#                    Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0             DG Bradman        52    80        10   6996                 334
# 1            PHKD Mendis        14    24         3   1316                 182
# 2               AC Voges        20    31         7   1485                 269
# 3             RG Pollock        23    41         4   2256                 274
# 4             GA Headley        22    40         4   2190                 270
# 5            H Sutcliffe        54    84         9   4555                 194
# 6              E Paynter        20    31         5   1540                 243
# 7          KF Barrington        82   131        15   6806                 256
# 8              ED Weekes        48    81         5   4455                 207
# 9             WR Hammond        85   140        16   7249                 336
# 10             GS Sobers        93   160        21   8032                 365
# 11              HC Brook        30    50         1   2820                 317
# 12         KC Sangakkara       134   233        17  12400                 319
# 13              JB Hobbs        61   102         7   5410                 211
# 14            CL Walcott        44    74         7   3798                 220
# 15              L Hutton        79   138        15   6971                 364
# 16             SPD Smith       119   212        25  10477                 239
# 17             JH Kallis       166   280        40  13289                 224
# 18          GE Tyldesley        14    20         2    990                 122
# 19         KS Williamson       105   186        17   9276                 251
# 20              CA Davis        15    29         5   1301                 183
# 21             VG Kambli        17    21         1   1084                 227
# 22           GS Chappell        87   151        19   7110                 247
# 23             AD Nourse        34    62         7   2960                 231
# 24          SR Tendulkar       200   329        33  15921                 248
# 25               BC Lara       131   232         6  11953                 400
# 26         Javed Miandad       124   189        21   8832                 280
# 27              R Dravid       164   286        32  13288                 270
# 28       Mohammad Yousuf        90   156        12   7530                 223
# 29           Younis Khan       118   213        19  10099                 313
# 30            RT Ponting       168   287        29  13378                 257
# 31           YBK Jaiswal        26    49         2   2428                 214
# 32               J Ryder        20    32         5   1394                 201
# 33              A Flower        63   112        19   4794                 232
# 34            MEK Hussey        79   137        16   6235                 195
# 35         S Chanderpaul       164   280        49  11867                 203
# 36               JE Root       158   288        24  13543                 262
# 37           SM Gavaskar       125   214        16  10122                 236
# 38              SR Waugh       168   260        46  10927                 200
# 39             ML Hayden       103   184        14   8625                 380
# 40        AB de Villiers       114   191        18   8765                 278
# 41             AR Border       156   265        44  11174                 205
# 42          IVA Richards       121   182        12   8540                 291
# 43           DCS Compton        78   131        15   5807                 278
# 44      DPMD Jayawardene       149   252        15  11814                 374
# 45        Inzamam-ul-Haq       120   200        22   8830                 329
# 46           FMM Worrell        51    87         9   3860                 261
# 47               CP Mead        17    26         2   1185                 182
# 48              V Sehwag       104   180         6   8586                 319
# 49              Abid Ali        16    26         2   1180                 215
# 50             MJ Clarke       115   198        22   8643                 329
# 51              KC Bland        21    39         5   1669                 144
# 52            B Mitchell        42    80         9   3471                 189
# 53              JL Smith        15    25         3   1075                 184
# 54        Hon.FS Jackson        20    33         4   1415                 144
# 55        TT Samaraweera        81   132        20   5462                 231
# 57            KD Walters        74   125        14   5357                 250
# 58              GC Smith       117   205        13   9265                 277
# 59           WH Ponsford        29    48         4   2122                 266
# 60             SJ McCabe        39    62         5   2748                 232
# 61  Hashmatullah Shahidi        11    21         5    771                 246
# 62            DR Jardine        22    33         6   1296                 127
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50     0     4s   6s  \
# 0   99.94        9800                58.60   29  13   7.0   626+    6
# 1   62.66        2063                63.79    5   5   NaN    137   24
# 2   61.87        2667                55.68    5   4   2.0    186    5
# 3   60.97        1707                54.48    7  11   1.0   246+   11
# 4   60.83         416                56.00   10   5   2.0   104+    1
# 5   60.73        6558                34.59   16  23   2.0   202+    6
# 6   59.23        1288                45.88    4   7   3.0   125+    4
# 7   58.67        4957                42.42   20  35   5.0   591+   27
# 8   58.61           0                 0.00   15  19   6.0   258+    2
# 9   58.45        7491                38.07   22  24   4.0   419+   27
# 10  57.78        4063                53.58   26  30  12.0   593+  32+
# 11  57.55        3222                87.52   10  13   3.0    308   47
# 12  57.40       22882                54.19   38  52  11.0   1491   51
# 13  56.94        5363                46.22   15  28   4.0   276+    8
# 14  56.68           0                 0.00   15  14   1.0   107+   11
# 15  56.67        2844                39.34   19  33   5.0   358+    7
# 16  56.02       19517                53.68   36  43  11.0   1143   62
# 17  55.37       28903                45.97   45  58  16.0   1488   97
# 18  55.00         178                29.21    3   6   2.0    37+    2
# 19  54.88       17913                51.78   33  37  11.0   1031   27
# 20  54.20         665                35.48    4   4   1.0    65+    1
# 21  54.20        1823                59.46    4   3   3.0    124    6
# 22  53.86       13079                51.53   24  31  12.0    755   16
# 23  53.81         108                63.88    9  14   3.0   115+    6
# 24  53.78       29437                54.04   51  68  14.0  2058+   69
# 25  52.88       19753                60.51   34  48  17.0   1559   88
# 26  52.57       15164                45.99   23  43   6.0   788+   48
# 27  52.31       31258                42.51   36  63   8.0   1654   21
# 28  52.29       14372                52.39   24  33  11.0    957   51
# 29  52.05       19375                52.12   34  33  19.0   1082   70
# 30  51.85       22782                58.72   41  62  17.0   1509   73
# 31  51.65        3655                66.42    7  12   5.0    301   43
# 32  51.62        2035                44.86    3   9   1.0   102+    3
# 33  51.54       10636                45.07   12  27   5.0    543   20
# 34  51.52       12436                50.13   19  29  12.0    685   39
# 35  51.37       27395                43.31   30  66  15.0   1285   36
# 36  51.29       23556                57.49   39  66  13.0   1451   45
# 37  51.12       14184                43.35   34  45  12.0   908+   26
# 38  51.06       22461                48.64   32  50  22.0   1175   20
# 39  50.73       14349                60.10   30  29  14.0   1049   82
# 40  50.66       16077                54.51   22  46   8.0   1024   64
# 41  50.56       27002                41.09   27  63  11.0   1161   28
# 42  50.23        9613                69.77   24  45  10.0   952+   84
# 43  50.06        2731                38.81   17  28  10.0   342+    3
# 44  49.84       22959                51.45   34  50  15.0   1387   61
# 45  49.60       16345                54.02   25  46  15.0   1105   48
# 46  49.48         488                40.16    9  22  11.0   240+   11
# 47  49.37         619                30.04    4   3   3.0    38+    0
# 48  49.34       10441                82.23   23  32  16.0   1233   91
# 49  49.16        2445                48.26    4   3   2.0    148    5
# 50  49.10       15456                55.92   28  27   9.0    978   39
# 51  49.08         885                37.74    3   9   2.0   123+   20
# 52  48.88         158                29.11    8  21   3.0    41+    1
# 53  48.86        1429                75.22    2   6   NaN    111   26
# 54  48.79           0                 0.00    5   6   3.0    51+    0
# 55  48.76       11641                46.92   14  30  11.0    633    7
# 57  48.26        8662                49.16   15  33   4.0   525+   23
# 58  48.25       15525                59.67   27  38  11.0   1165   24
# 59  48.22        3118                44.77    7   6   1.0   119+    0
# 60  48.21        3217                60.02    6  13   4.0   241+   5+
# 61  48.18        1629                47.32    2   2   NaN     87    1
# 62  48.00        2110                25.59    1  10   2.0    53+    0
#
#    Rookie_Year Final_Year  Country
# 0         1928       1948      AUS
# 1         2022       2025       SL
# 2         2015       2016      AUS
# 3         1963       1970       SA
# 4         1930       1954       WI
# 5         1924       1935      ENG
# 6         1931       1939      ENG
# 7         1955       1968      ENG
# 8         1948       1958       WI
# 9         1927       1947      ENG
# 10        1954       1974       WI
# 11        2022       2025      ENG
# 12        2000       2015       SL
# 13        1908       1930      ENG
# 14        1948       1960       WI
# 15        1937       1955      ENG
# 16        2010       2025      AUS
# 17        1995       2013   ICC/SA
# 18        1921       1929      ENG
# 19        2010       2024       NZ
# 20        1968       1973       WI
# 21        1993       1995      IND
# 22        1970       1984      AUS
# 23        1935       1951       SA
# 24        1989       2013      IND
# 25        1990       2006   ICC/WI
# 26        1976       1993      PAK
# 27        1996       2012  ICC/IND
# 28        1998       2010      PAK
# 29        2000       2017      PAK
# 30        1995       2012      AUS
# 31        2023       2025      IND
# 32        1920       1929      AUS
# 33        1992       2002      ZIM
# 34        2005       2013      AUS
# 35        1994       2015       WI
# 36        2012       2025      ENG
# 37        1971       1987      IND
# 38        1985       2004      AUS
# 39        1994       2009      AUS
# 40        2004       2018       SA
# 41        1978       1994      AUS
# 42        1974       1991       WI
# 43        1937       1957      ENG
# 44        1997       2014       SL
# 45        1992       2007  ICC/PAK
# 46        1948       1963       WI
# 47        1911       1928      ENG
# 48        2001       2013  ICC/IND
# 49        2019       2021      PAK
# 50        2004       2015      AUS
# 51        1961       1966       SA
# 52        1929       1949       SA
# 53        2024       2025      ENG
# 54        1893       1905      ENG
# 55        2001       2013       SL
# 57        1965       1981      AUS
# 58        2002       2014   ICC/SA
# 59        1924       1934      AUS
# 60        1930       1938      AUS
# 61        2018       2025      AFG
# 62        1928       1934      ENG

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                       True
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].astype('float')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Final_Year'] = df['Final_Year'].astype('int')

# %%
df['Rookie_Year'] = df['Rookie_Year'].astype('int')

# %%
df['career_length'] = df['Final_Year'] - df['Rookie_Year']

# %%
df
# Out:
#                    Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0             DG Bradman        52    80        10   6996                 334
# 1            PHKD Mendis        14    24         3   1316                 182
# 2               AC Voges        20    31         7   1485                 269
# 3             RG Pollock        23    41         4   2256                 274
# 4             GA Headley        22    40         4   2190                 270
# 5            H Sutcliffe        54    84         9   4555                 194
# 6              E Paynter        20    31         5   1540                 243
# 7          KF Barrington        82   131        15   6806                 256
# 8              ED Weekes        48    81         5   4455                 207
# 9             WR Hammond        85   140        16   7249                 336
# 10             GS Sobers        93   160        21   8032                 365
# 11              HC Brook        30    50         1   2820                 317
# 12         KC Sangakkara       134   233        17  12400                 319
# 13              JB Hobbs        61   102         7   5410                 211
# 14            CL Walcott        44    74         7   3798                 220
# 15              L Hutton        79   138        15   6971                 364
# 16             SPD Smith       119   212        25  10477                 239
# 17             JH Kallis       166   280        40  13289                 224
# 18          GE Tyldesley        14    20         2    990                 122
# 19         KS Williamson       105   186        17   9276                 251
# 20              CA Davis        15    29         5   1301                 183
# 21             VG Kambli        17    21         1   1084                 227
# 22           GS Chappell        87   151        19   7110                 247
# 23             AD Nourse        34    62         7   2960                 231
# 24          SR Tendulkar       200   329        33  15921                 248
# 25               BC Lara       131   232         6  11953                 400
# 26         Javed Miandad       124   189        21   8832                 280
# 27              R Dravid       164   286        32  13288                 270
# 28       Mohammad Yousuf        90   156        12   7530                 223
# 29           Younis Khan       118   213        19  10099                 313
# 30            RT Ponting       168   287        29  13378                 257
# 31           YBK Jaiswal        26    49         2   2428                 214
# 32               J Ryder        20    32         5   1394                 201
# 33              A Flower        63   112        19   4794                 232
# 34            MEK Hussey        79   137        16   6235                 195
# 35         S Chanderpaul       164   280        49  11867                 203
# 36               JE Root       158   288        24  13543                 262
# 37           SM Gavaskar       125   214        16  10122                 236
# 38              SR Waugh       168   260        46  10927                 200
# 39             ML Hayden       103   184        14   8625                 380
# 40        AB de Villiers       114   191        18   8765                 278
# 41             AR Border       156   265        44  11174                 205
# 42          IVA Richards       121   182        12   8540                 291
# 43           DCS Compton        78   131        15   5807                 278
# 44      DPMD Jayawardene       149   252        15  11814                 374
# 45        Inzamam-ul-Haq       120   200        22   8830                 329
# 46           FMM Worrell        51    87         9   3860                 261
# 47               CP Mead        17    26         2   1185                 182
# 48              V Sehwag       104   180         6   8586                 319
# 49              Abid Ali        16    26         2   1180                 215
# 50             MJ Clarke       115   198        22   8643                 329
# 51              KC Bland        21    39         5   1669                 144
# 52            B Mitchell        42    80         9   3471                 189
# 53              JL Smith        15    25         3   1075                 184
# 54        Hon.FS Jackson        20    33         4   1415                 144
# 55        TT Samaraweera        81   132        20   5462                 231
# 57            KD Walters        74   125        14   5357                 250
# 58              GC Smith       117   205        13   9265                 277
# 59           WH Ponsford        29    48         4   2122                 266
# 60             SJ McCabe        39    62         5   2748                 232
# 61  Hashmatullah Shahidi        11    21         5    771                 246
# 62            DR Jardine        22    33         6   1296                 127
#
#       Ave  Balls_Faced  Batting_Strike_Rate  100  50     0     4s   6s  \
# 0   99.94         9800                58.60   29  13   7.0   626+    6
# 1   62.66         2063                63.79    5   5   NaN    137   24
# 2   61.87         2667                55.68    5   4   2.0    186    5
# 3   60.97         1707                54.48    7  11   1.0   246+   11
# 4   60.83          416                56.00   10   5   2.0   104+    1
# 5   60.73         6558                34.59   16  23   2.0   202+    6
# 6   59.23         1288                45.88    4   7   3.0   125+    4
# 7   58.67         4957                42.42   20  35   5.0   591+   27
# 8   58.61            0                 0.00   15  19   6.0   258+    2
# 9   58.45         7491                38.07   22  24   4.0   419+   27
# 10  57.78         4063                53.58   26  30  12.0   593+  32+
# 11  57.55         3222                87.52   10  13   3.0    308   47
# 12  57.40        22882                54.19   38  52  11.0   1491   51
# 13  56.94         5363                46.22   15  28   4.0   276+    8
# 14  56.68            0                 0.00   15  14   1.0   107+   11
# 15  56.67         2844                39.34   19  33   5.0   358+    7
# 16  56.02        19517                53.68   36  43  11.0   1143   62
# 17  55.37        28903                45.97   45  58  16.0   1488   97
# 18  55.00          178                29.21    3   6   2.0    37+    2
# 19  54.88        17913                51.78   33  37  11.0   1031   27
# 20  54.20          665                35.48    4   4   1.0    65+    1
# 21  54.20         1823                59.46    4   3   3.0    124    6
# 22  53.86        13079                51.53   24  31  12.0    755   16
# 23  53.81          108                63.88    9  14   3.0   115+    6
# 24  53.78        29437                54.04   51  68  14.0  2058+   69
# 25  52.88        19753                60.51   34  48  17.0   1559   88
# 26  52.57        15164                45.99   23  43   6.0   788+   48
# 27  52.31        31258                42.51   36  63   8.0   1654   21
# 28  52.29        14372                52.39   24  33  11.0    957   51
# 29  52.05        19375                52.12   34  33  19.0   1082   70
# 30  51.85        22782                58.72   41  62  17.0   1509   73
# 31  51.65         3655                66.42    7  12   5.0    301   43
# 32  51.62         2035                44.86    3   9   1.0   102+    3
# 33  51.54        10636                45.07   12  27   5.0    543   20
# 34  51.52        12436                50.13   19  29  12.0    685   39
# 35  51.37        27395                43.31   30  66  15.0   1285   36
# 36  51.29        23556                57.49   39  66  13.0   1451   45
# 37  51.12        14184                43.35   34  45  12.0   908+   26
# 38  51.06        22461                48.64   32  50  22.0   1175   20
# 39  50.73        14349                60.10   30  29  14.0   1049   82
# 40  50.66        16077                54.51   22  46   8.0   1024   64
# 41  50.56        27002                41.09   27  63  11.0   1161   28
# 42  50.23         9613                69.77   24  45  10.0   952+   84
# 43  50.06         2731                38.81   17  28  10.0   342+    3
# 44  49.84        22959                51.45   34  50  15.0   1387   61
# 45  49.60        16345                54.02   25  46  15.0   1105   48
# 46  49.48          488                40.16    9  22  11.0   240+   11
# 47  49.37          619                30.04    4   3   3.0    38+    0
# 48  49.34        10441                82.23   23  32  16.0   1233   91
# 49  49.16         2445                48.26    4   3   2.0    148    5
# 50  49.10        15456                55.92   28  27   9.0    978   39
# 51  49.08          885                37.74    3   9   2.0   123+   20
# 52  48.88          158                29.11    8  21   3.0    41+    1
# 53  48.86         1429                75.22    2   6   NaN    111   26
# 54  48.79            0                 0.00    5   6   3.0    51+    0
# 55  48.76        11641                46.92   14  30  11.0    633    7
# 57  48.26         8662                49.16   15  33   4.0   525+   23
# 58  48.25        15525                59.67   27  38  11.0   1165   24
# 59  48.22         3118                44.77    7   6   1.0   119+    0
# 60  48.21         3217                60.02    6  13   4.0   241+   5+
# 61  48.18         1629                47.32    2   2   NaN     87    1
# 62  48.00         2110                25.59    1  10   2.0    53+    0
#
#     Rookie_Year  Final_Year  Country  career_length
# 0          1928        1948      AUS             20
# 1          2022        2025       SL              3
# 2          2015        2016      AUS              1
# 3          1963        1970       SA              7
# 4          1930        1954       WI             24
# 5          1924        1935      ENG             11
# 6          1931        1939      ENG              8
# 7          1955        1968      ENG             13
# 8          1948        1958       WI             10
# 9          1927        1947      ENG             20
# 10         1954        1974       WI             20
# 11         2022        2025      ENG              3
# 12         2000        2015       SL             15
# 13         1908        1930      ENG             22
# 14         1948        1960       WI             12
# 15         1937        1955      ENG             18
# 16         2010        2025      AUS             15
# 17         1995        2013   ICC/SA             18
# 18         1921        1929      ENG              8
# 19         2010        2024       NZ             14
# 20         1968        1973       WI              5
# 21         1993        1995      IND              2
# 22         1970        1984      AUS             14
# 23         1935        1951       SA             16
# 24         1989        2013      IND             24
# 25         1990        2006   ICC/WI             16
# 26         1976        1993      PAK             17
# 27         1996        2012  ICC/IND             16
# 28         1998        2010      PAK             12
# 29         2000        2017      PAK             17
# 30         1995        2012      AUS             17
# 31         2023        2025      IND              2
# 32         1920        1929      AUS              9
# 33         1992        2002      ZIM             10
# 34         2005        2013      AUS              8
# 35         1994        2015       WI             21
# 36         2012        2025      ENG             13
# 37         1971        1987      IND             16
# 38         1985        2004      AUS             19
# 39         1994        2009      AUS             15
# 40         2004        2018       SA             14
# 41         1978        1994      AUS             16
# 42         1974        1991       WI             17
# 43         1937        1957      ENG             20
# 44         1997        2014       SL             17
# 45         1992        2007  ICC/PAK             15
# 46         1948        1963       WI             15
# 47         1911        1928      ENG             17
# 48         2001        2013  ICC/IND             12
# 49         2019        2021      PAK              2
# 50         2004        2015      AUS             11
# 51         1961        1966       SA              5
# 52         1929        1949       SA             20
# 53         2024        2025      ENG              1
# 54         1893        1905      ENG             12
# 55         2001        2013       SL             12
# 57         1965        1981      AUS             16
# 58         2002        2014   ICC/SA             12
# 59         1924        1934      AUS             10
# 60         1930        1938      AUS              8
# 61         2018        2025      AFG              7
# 62         1928        1934      ENG              6

# %%
df['career_length'].mean()
# Out:
# 12.838709677419354

# %% [markdown]
# ### AVG Batting_Strike_Rate for cricketers who played over 10 years

# %%
df[df['career_length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# 47.90190476190477

# %%
df[df['Rookie_Year'] < 1960]['Player'].count()
# Out:
# 22

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('Highinncountry').reset_index().sort_values('Highinncountry', ascending = False)
# Out:
#     Country  Highinncountry
# 6    ICC/WI             400
# 1       AUS             380
# 11       SL             374
# 12       WI             365
# 2       ENG             364
# 4   ICC/PAK             329
# 3   ICC/IND             319
# 9       PAK             313
# 10       SA             278
# 5    ICC/SA             277
# 8        NZ             251
# 7       IND             248
# 0       AFG             246
# 13      ZIM             232

# %%
df.groupby('Country')[['100', '50', '0']].mean()
# Out:
#                100         50          0
# Country
# AFG       2.000000   2.000000        NaN
# AUS      21.571429  29.428571   9.071429
# ENG      12.642857  20.571429   4.538462
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      24.000000  32.000000   8.500000
# NZ       33.000000  37.000000  11.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       22.750000  34.250000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
